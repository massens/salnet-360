# %%
from keras.models import load_model
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage
import numpy as np
import sys
sys.path.append('/root/sharedfolder/salnet_360/')
import model1 as salnet
reload(salnet)
# Out:
# <module 'model1' from '/root/sharedfolder/salnet_keras/model1.pyc'>

# %%
#model = load_model('../model_2.h5')
model = salnet.get_model()
model.load_weights('/root/sharedfolder/salnet_keras/output/model1_salnet_keras_5/final.weights')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-9d57c852e122> in <module>()
#       1 #model = load_model('../model_2.h5')
#       2 model = salnet.get_model()
# ----> 3 model.load_weights('/root/sharedfolder/salnet_keras/output/model1_salnet_keras_5/final.weights')
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/topology.pyc in load_weights(self, filepath, by_name)
#    2706             self.load_weights_from_hdf5_group_by_name(f)
#    2707         else:
# -> 2708             self.load_weights_from_hdf5_group(f)
#    2709
#    2710         if hasattr(f, 'close'):
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/topology.pyc in load_weights_from_hdf5_group(self, f)
#    2758                                  'containing ' + str(len(layer_names)) +
#    2759                                  ' layers into a model with ' +
# -> 2760                                  str(len(flattened_layers)) + ' layers.')
#    2761
#    2762             # We batch weight value assignments in a single backend call
#
# ValueError: You are trying to load a weight file containing 14 layers into a model with 11 layers.

# %%
preds = model.predict(X_val[:10])

# %%
img_id = 4
plt.figure(1, figsize=(15,30))
blured= ndimage.gaussian_filter(preds[img_id], sigma=3)
sal_map = blured
sal_map -= np.min(sal_map)
sal_map /= np.max(sal_map)
print sal_map.shape
plt.subplot(1,3,2)
plt.imshow(sal_map[0])
plt.title('Prediction')

plt.subplot(1,3,3)
plt.imshow(Y_val[img_id,0,:,:])
plt.title('Ground Truth')
#plt.imshow(preds[0])

plt.subplot(1,3,1)
plt.imshow(X_val[img_id].transpose((1,2,0)).astype(np.uint8))
# Out:
# (1, 240, 320)
